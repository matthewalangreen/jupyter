# %% [markdown]
# tutorial: https://www.shanelynn.ie/python-pandas-read_csv-load-data-from-csv-files/
# data: https://data.humdata.org/dataset/novel-coronavirus-2019-ncov-cases

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("COVID/data/covid.csv")

# %%
data.head()
# Out:
#   Province/State Country/Region       Lat      Long  1/22/20  1/23/20  \
# 0     #adm1+name  #country+name  #geo+lat  #geo+lon      NaN      NaN
# 1            NaN    Afghanistan      33.0      65.0      0.0      0.0
# 2            NaN        Albania   41.1533   20.1683      0.0      0.0
# 3            NaN        Algeria   28.0339    1.6596      0.0      0.0
# 4            NaN        Andorra   42.5063    1.5218      0.0      0.0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  \
# 0      NaN      NaN      NaN      NaN  ...     NaN     NaN     NaN
# 1      0.0      0.0      0.0      0.0  ...    15.0    18.0    18.0
# 2      0.0      0.0      0.0      0.0  ...   104.0   116.0   131.0
# 3      0.0      0.0      0.0      0.0  ...    90.0    90.0   113.0
# 4      0.0      0.0      0.0      0.0  ...    26.0    31.0    39.0
#
#    ISO 3166-1 Alpha 3-Codes        Region Code        Region Name  \
# 0             #country+code  #region+main+code  #region+main+name
# ...
